# %% [markdown]
# <a href="https://colab.research.google.com/github/soham-wairkar/CE888/blob/main/LAB4/My_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
jester = pd.read_csv('https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv', header=None)
jester.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
jester.describe().transpose()
# Out:
#        count       mean        std    min     25%    50%    75%    max
# 0    24983.0  72.467478  21.859600  36.00  53.000  72.00  100.0  100.0
# 1    24983.0  34.401435  46.707059  -9.95  -0.150   5.05   99.0   99.0
# 2    24983.0  27.094089  44.228006  -9.95  -2.180   3.69   99.0   99.0
# 3    24983.0  33.263717  46.747535  -9.95  -1.145   4.66   99.0   99.0
# 4    24983.0  36.244936  48.812967  -9.95  -3.350   3.45   99.0   99.0
# ..       ...        ...        ...    ...     ...    ...    ...    ...
# 96   24983.0  58.541104  48.130562  -9.95   3.300  99.00   99.0   99.0
# 97   24983.0  58.017246  48.164681  -9.95   3.590  99.00   99.0   99.0
# 98   24983.0  57.061650  48.717455  -9.95   2.670  99.00   99.0   99.0
# 99   24983.0  55.753357  49.237139  -9.95   1.335  99.00   99.0   99.0
# 100  24983.0  60.138090  47.913531  -9.95   3.930  99.00   99.0   99.0
#
# [101 rows x 8 columns]

# %%
jester_nan = jester.replace(99, np.nan)

# %%
jester_nan.isna().sum()
# Out:
# 0         81
# 1       8531
# 2       6799
# 3       8341
# 4       9375
#        ...
# 96     14613
# 97     14463
# 98     14317
# 99     14073
# 100    15040
# Length: 101, dtype: int64

# %%
len(jester[0].unique())
# Out:
# 65

# %%
jester_nan.drop(columns=0, axis=1, inplace=True)

# %%
jester_nan.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 100 columns]

# %%
jester_nan.mean().sort_values(ascending=True)
# Out:
# 58   -3.833880
# 16   -3.104818
# 44   -2.111891
# 57   -1.990664
# 13   -1.762882
#         ...
# 32    3.155988
# 27    3.189821
# 36    3.312500
# 89    3.574720
# 50    3.665085
# Length: 100, dtype: float64

# %%
arr = jester_nan.values

# %%
np.where(arr!= 99)
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([ 0,  1,  2, ..., 97, 98, 99]))

# %%
def helper_function(orig, percentage=0.1):
  """
  Replaces 'percentage'% of the original values in 'orig' with 99's
  :param orig: original data array
  :param percentage: percentage of values to replace (0<percentage<1)
  """
  new_data = orig.copy()
  rated = np.where(~np.isnan(orig))
  n_rated = len(rated[0])
  idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
  new_data[rated[0][idx], rated[1][idx]] = 99
  return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = helper_function(arr)

# %%
arr[idx[0][0], idx[1][0]]
# Out:
# 4.22

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %%
jester.groupby(0).count()
# Out:
#       1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0                                        ...
# 36    482   482   482   482   482   482  ...   482   482   482   482   482   482
# 37    409   409   409   409   409   409  ...   409   409   409   409   409   409
# 38    413   413   413   413   413   413  ...   413   413   413   413   413   413
# 39    391   391   391   391   391   391  ...   391   391   391   391   391   391
# 40    407   407   407   407   407   407  ...   407   407   407   407   407   407
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 96     68    68    68    68    68    68  ...    68    68    68    68    68    68
# 97     60    60    60    60    60    60  ...    60    60    60    60    60    60
# 98     71    71    71    71    71    71  ...    71    71    71    71    71    71
# 99     81    81    81    81    81    81  ...    81    81    81    81    81    81
# 100  7200  7200  7200  7200  7200  7200  ...  7200  7200  7200  7200  7200  7200
#
# [65 rows x 100 columns]

# %%
users = jester[0].unique()
users
# Out:
# array([ 74, 100,  49,  48,  91,  47,  72,  36,  51,  53,  55,  50,  67,
#         60,  54,  46,  38,  41,  73,  92,  89,  71,  40,  45,  62,  63,
#         61,  65,  68,  69,  37,  56,  66,  64,  82,  57,  75,  88,  86,
#         43,  83,  93,  94,  44,  59,  39,  58,  70,  78,  97,  90,  84,
#         98,  96,  52,  80,  42,  81,  76,  79,  85,  77,  95,  87,  99])

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)


def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err
    

def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if not np.isnan(rating):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 5) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
n_latent_factors = 4

user_ratings = jester_nan.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %% [markdown]
# ##**MSE of validation set**

# %%
err  =[]
for u, i in zip(*idx):
  err.append(predict_rating(u,i) - user_ratings[u,i])
print('MSE of validation set: ', (np.array(err)**2).mean())
# Out:
# MSE of validation set:  27.856494328963336

# %% [markdown]
# ##**Prediction of test set**

# %%
test_idx = np.where(np.isnan(user_ratings))
for u, i in zip(*test_idx):
  print('Prediction for {} user_id for item_id {} is {}'.format(u, i, predict_rating(u,i)))
# Out:
# Streaming output truncated to the last 5000 lines.
# Prediction for 24812 user_id for item_id 92 is 0.3192205462425646
# Prediction for 24812 user_id for item_id 93 is 0.4031667916228928
# Prediction for 24812 user_id for item_id 94 is 0.8004132288053211
# Prediction for 24812 user_id for item_id 95 is 0.34103992208030887
# Prediction for 24813 user_id for item_id 70 is 1.8282072877809066
# Prediction for 24813 user_id for item_id 71 is 1.2880110291486928
# Prediction for 24813 user_id for item_id 72 is 1.1495001932026734
# Prediction for 24813 user_id for item_id 73 is 1.264966784816425
# Prediction for 24813 user_id for item_id 74 is 1.9457423162233711
# Prediction for 24813 user_id for item_id 75 is 2.0699623592706136
# Prediction for 24813 user_id for item_id 76 is 0.9906314299795356
# Prediction for 24813 user_id for item_id 77 is 1.3701387714445294
# Prediction for 24813 user_id for item_id 78 is 1.639598420850034
# Prediction for 24813 user_id for item_id 79 is 0.28306251825938955
# Prediction for 24813 user_id for item_id 80 is 1.192941497007878
# Prediction for 24813 user_id for item_id 81 is 0.6323601654265781
# Prediction for 24813 user_id for item_id 83 is 1.4981721444978164
# Prediction for 24813 user_id for item_id 85 is 1.855467377792986
# Prediction for 24813 user_id for item_id 86 is 0.9930891181206847
# Prediction for 24813 user_id for item_id 87 is 1.5870574685205951
# Prediction for 24813 user_id for item_id 88 is 1.29131246119583
# Prediction for 24813 user_id for item_id 89 is 1.808574859441115
# Prediction for 24813 user_id for item_id 90 is 1.4210068260639563
# Prediction for 24813 user_id for item_id 91 is 1.1734231441749248
# Prediction for 24813 user_id for item_id 92 is 0.5325942188406008
# Prediction for 24813 user_id for item_id 93 is 1.3414584179745765
# Prediction for 24813 user_id for item_id 95 is 0.8729582851577532
# Prediction for 24813 user_id for item_id 96 is 1.7755257105939282
# Prediction for 24813 user_id for item_id 97 is 1.436150092684173
# Prediction for 24813 user_id for item_id 98 is 1.8706689301678043
# Prediction for 24813 user_id for item_id 99 is 1.1682340600370529
# Prediction for 24814 user_id for item_id 0 is 0.7693332788647074
# Prediction for 24814 user_id for item_id 1 is 1.0896768466176743
# Prediction for 24814 user_id for item_id 2 is 1.4728508898775414
# Prediction for 24814 user_id for item_id 3 is 0.9950183965595184
# Prediction for 24814 user_id for item_id 5 is 1.0655136829337994
# Prediction for 24814 user_id for item_id 8 is 1.3030134956021382
# Prediction for 24814 user_id for item_id 9 is 0.7992071049843298
# Prediction for 24814 user_id for item_id 10 is 0.9503328799520779
# Prediction for 24814 user_id for item_id 11 is 0.7648322571329337
# Prediction for 24814 user_id for item_id 13 is 1.013982695210388
# Prediction for 24814 user_id for item_id 21 is 1.2425736691283105
# Prediction for 24814 user_id for item_id 22 is 1.183995150909022
# Prediction for 24814 user_id for item_id 23 is 0.7554173354694651
# Prediction for 24814 user_id for item_id 24 is 0.25896871585825515
# Prediction for 24814 user_id for item_id 25 is 0.6555424260807056
# Prediction for 24814 user_id for item_id 28 is 0.816213483037025
# Prediction for 24814 user_id for item_id 29 is 1.2354455735308352
# Prediction for 24814 user_id for item_id 32 is 1.172641607215277
# Prediction for 24814 user_id for item_id 36 is 1.1165415779123904
# Prediction for 24814 user_id for item_id 37 is 0.5779849863983324
# Prediction for 24814 user_id for item_id 38 is 1.1394901537139484
# Prediction for 24814 user_id for item_id 40 is 1.1068304654865375
# Prediction for 24814 user_id for item_id 42 is 1.1034962570480815
# Prediction for 24814 user_id for item_id 43 is 1.1580996651572075
# Prediction for 24814 user_id for item_id 44 is 0.7321445848154705
# Prediction for 24814 user_id for item_id 50 is 0.7688481648980744
# Prediction for 24814 user_id for item_id 51 is 0.9822163822951379
# Prediction for 24814 user_id for item_id 53 is 0.6958250061196595
# Prediction for 24814 user_id for item_id 54 is 1.1439620747143515
# Prediction for 24814 user_id for item_id 56 is 1.435191533389295
# Prediction for 24814 user_id for item_id 57 is 0.681529445234928
# Prediction for 24814 user_id for item_id 58 is 1.4878060278020877
# Prediction for 24814 user_id for item_id 59 is 1.2867372762453628
# Prediction for 24814 user_id for item_id 62 is 0.5568865064499007
# Prediction for 24814 user_id for item_id 63 is 0.9440284333600868
# Prediction for 24814 user_id for item_id 66 is 1.340145814193743
# Prediction for 24814 user_id for item_id 71 is 0.9291201164165556
# Prediction for 24814 user_id for item_id 72 is 0.8578423769119241
# Prediction for 24814 user_id for item_id 73 is 0.8152514044670677
# Prediction for 24814 user_id for item_id 74 is 1.3695389812450174
# Prediction for 24814 user_id for item_id 75 is 1.4968319565321426
# Prediction for 24814 user_id for item_id 76 is 0.6831686674328704
# Prediction for 24814 user_id for item_id 77 is 0.9334564218044918
# Prediction for 24814 user_id for item_id 78 is 1.1414809117695797
# Prediction for 24814 user_id for item_id 79 is 0.18428843723064112
# Prediction for 24814 user_id for item_id 80 is 0.8033120462609857
# Prediction for 24814 user_id for item_id 81 is 0.38469108797668355
# Prediction for 24814 user_id for item_id 82 is 0.5916832677224438
# Prediction for 24814 user_id for item_id 83 is 0.9792889419902598
# Prediction for 24814 user_id for item_id 84 is 1.3245473819739177
# Prediction for 24814 user_id for item_id 85 is 1.301194340655514
# Prediction for 24814 user_id for item_id 87 is 1.1357212041001055
# Prediction for 24814 user_id for item_id 88 is 0.9078712330477743
# Prediction for 24814 user_id for item_id 89 is 1.205816743861461
# Prediction for 24814 user_id for item_id 90 is 0.9926868250731583
# Prediction for 24814 user_id for item_id 91 is 0.797280285277393
# Prediction for 24814 user_id for item_id 92 is 0.3581659636894106
# Prediction for 24814 user_id for item_id 93 is 0.9131675515126815
# Prediction for 24814 user_id for item_id 95 is 0.6284612870678257
# Prediction for 24814 user_id for item_id 96 is 1.2459572385819473
# Prediction for 24814 user_id for item_id 97 is 0.957916701047758
# Prediction for 24814 user_id for item_id 98 is 1.2541320108384966
# Prediction for 24814 user_id for item_id 99 is 0.8427918072457076
# Prediction for 24815 user_id for item_id 70 is 0.9527558112104506
# Prediction for 24815 user_id for item_id 71 is 0.6289816686578631
# Prediction for 24815 user_id for item_id 72 is 0.6644931861064018
# Prediction for 24815 user_id for item_id 73 is 0.8292660764446719
# Prediction for 24815 user_id for item_id 74 is 1.1344172334784348
# Prediction for 24815 user_id for item_id 75 is 1.159856162837385
# Prediction for 24815 user_id for item_id 76 is 0.6198252184188591
# Prediction for 24815 user_id for item_id 77 is 0.9287787504922742
# Prediction for 24815 user_id for item_id 78 is 1.047897315445246
# Prediction for 24815 user_id for item_id 79 is 0.17716572809774425
# Prediction for 24815 user_id for item_id 80 is 0.6155314330449586
# Prediction for 24815 user_id for item_id 81 is 0.3637971250321445
# Prediction for 24815 user_id for item_id 82 is 0.3997768645125584
# Prediction for 24815 user_id for item_id 83 is 0.7690467794256308
# Prediction for 24815 user_id for item_id 84 is 1.0321446431273151
# Prediction for 24815 user_id for item_id 85 is 1.0799110804224894
# Prediction for 24815 user_id for item_id 87 is 0.804660321331705
# Prediction for 24815 user_id for item_id 88 is 0.6925553701393388
# Prediction for 24815 user_id for item_id 89 is 1.1432511390654443
# Prediction for 24815 user_id for item_id 90 is 0.8153620271962458
# Prediction for 24815 user_id for item_id 91 is 0.6915350963596134
# Prediction for 24815 user_id for item_id 92 is 0.283821718080146
# Prediction for 24815 user_id for item_id 93 is 0.7837072889754289
# Prediction for 24815 user_id for item_id 94 is 0.893995220300406
# Prediction for 24815 user_id for item_id 95 is 0.5305869664041241
# Prediction for 24815 user_id for item_id 97 is 0.9173557558231562
# Prediction for 24815 user_id for item_id 98 is 1.0033281683420954
# Prediction for 24815 user_id for item_id 99 is 0.6360467160276683
# Prediction for 24816 user_id for item_id 0 is 0.34211975652460724
# Prediction for 24816 user_id for item_id 1 is 0.7763313082751525
# Prediction for 24816 user_id for item_id 2 is 1.0283054980254769
# Prediction for 24816 user_id for item_id 3 is 0.49581226809796636
# Prediction for 24816 user_id for item_id 8 is 1.1673194426543383
# Prediction for 24816 user_id for item_id 9 is 0.7387000772522646
# Prediction for 24816 user_id for item_id 11 is 0.49952219431916867
# Prediction for 24816 user_id for item_id 21 is 1.1290015802780413
# Prediction for 24816 user_id for item_id 22 is 0.7115396619580654
# Prediction for 24816 user_id for item_id 23 is 0.46278196587065223
# Prediction for 24816 user_id for item_id 24 is 0.1646952237202993
# Prediction for 24816 user_id for item_id 29 is 0.6658052356946687
# Prediction for 24816 user_id for item_id 32 is 1.1381911270219633
# Prediction for 24816 user_id for item_id 33 is 0.06360547968258769
# Prediction for 24816 user_id for item_id 36 is 0.6652123098895331
# Prediction for 24816 user_id for item_id 37 is 0.24959453463550094
# Prediction for 24816 user_id for item_id 40 is 0.6419644380495036
# Prediction for 24816 user_id for item_id 42 is 0.7710616163817262
# Prediction for 24816 user_id for item_id 43 is 0.7825991642079511
# Prediction for 24816 user_id for item_id 44 is 0.7576952639805423
# Prediction for 24816 user_id for item_id 45 is 0.5175219050520916
# Prediction for 24816 user_id for item_id 46 is 0.96883758985411
# Prediction for 24816 user_id for item_id 50 is 0.3607401267018745
# Prediction for 24816 user_id for item_id 54 is 1.0464183526538682
# Prediction for 24816 user_id for item_id 57 is 0.3388659382207016
# Prediction for 24816 user_id for item_id 58 is 1.0641743357095774
# Prediction for 24816 user_id for item_id 59 is 0.7627703159172453
# Prediction for 24816 user_id for item_id 62 is 0.3288101964802121
# Prediction for 24816 user_id for item_id 63 is 0.7639883128311172
# Prediction for 24816 user_id for item_id 66 is 1.0140931632262586
# Prediction for 24816 user_id for item_id 69 is 0.9610918597726403
# Prediction for 24816 user_id for item_id 70 is 0.7450211894840228
# Prediction for 24816 user_id for item_id 71 is 0.8822235031191068
# Prediction for 24816 user_id for item_id 72 is 0.4670997787030352
# Prediction for 24816 user_id for item_id 73 is 0.780097735775357
# Prediction for 24816 user_id for item_id 74 is 0.941327044959424
# Prediction for 24816 user_id for item_id 75 is 1.1261987665945457
# Prediction for 24816 user_id for item_id 76 is 0.18809205989260344
# Prediction for 24816 user_id for item_id 77 is 0.6527296713049032
# Prediction for 24816 user_id for item_id 78 is 0.7137882598144395
# Prediction for 24816 user_id for item_id 79 is 0.16644871952116308
# Prediction for 24816 user_id for item_id 80 is 0.5239494385829591
# Prediction for 24816 user_id for item_id 81 is 0.25976808487231984
# Prediction for 24816 user_id for item_id 82 is 0.34686651544569547
# Prediction for 24816 user_id for item_id 83 is 0.7246164077896251
# Prediction for 24816 user_id for item_id 84 is 0.9865996436487269
# Prediction for 24816 user_id for item_id 85 is 0.9993955204004793
# Prediction for 24816 user_id for item_id 86 is 0.4425651987165193
# Prediction for 24816 user_id for item_id 87 is 0.8130985645914984
# Prediction for 24816 user_id for item_id 88 is 0.7807151729795035
# Prediction for 24816 user_id for item_id 89 is 0.963616617158102
# Prediction for 24816 user_id for item_id 90 is 0.8237298373569989
# Prediction for 24816 user_id for item_id 91 is 0.6835453034035711
# Prediction for 24816 user_id for item_id 92 is 0.2446580752607984
# Prediction for 24816 user_id for item_id 93 is 0.35900756027458025
# Prediction for 24816 user_id for item_id 94 is 0.7982203785408437
# Prediction for 24816 user_id for item_id 95 is 0.32399819065564883
# Prediction for 24816 user_id for item_id 97 is 0.8864047947478827
# Prediction for 24816 user_id for item_id 99 is 0.6079697988952463
# Prediction for 24817 user_id for item_id 0 is 1.27336858721987
# Prediction for 24817 user_id for item_id 2 is 2.0296402682551555
# Prediction for 24817 user_id for item_id 3 is 1.5790609565732587
# Prediction for 24817 user_id for item_id 8 is 1.468276419860119
# Prediction for 24817 user_id for item_id 23 is 1.0828512904590537
# Prediction for 24817 user_id for item_id 36 is 1.6249225395313986
# Prediction for 24817 user_id for item_id 43 is 1.587253552556049
# Prediction for 24817 user_id for item_id 56 is 1.9622815765920514
# Prediction for 24817 user_id for item_id 57 is 1.1777463981056315
# Prediction for 24817 user_id for item_id 70 is 1.8315219857397589
# Prediction for 24817 user_id for item_id 71 is 1.1033934285493578
# Prediction for 24817 user_id for item_id 73 is 0.7158711924763905
# Prediction for 24817 user_id for item_id 74 is 1.8525347433544805
# Prediction for 24817 user_id for item_id 75 is 2.0124658560931508
# Prediction for 24817 user_id for item_id 76 is 1.1666912086754664
# Prediction for 24817 user_id for item_id 77 is 1.1406956490577629
# Prediction for 24817 user_id for item_id 78 is 1.552490725661299
# Prediction for 24817 user_id for item_id 79 is 0.1791464390202702
# Prediction for 24817 user_id for item_id 80 is 1.0937125744006762
# Prediction for 24817 user_id for item_id 81 is 0.429660443592347
# Prediction for 24817 user_id for item_id 82 is 0.9193433755919752
# Prediction for 24817 user_id for item_id 84 is 1.7928907425499336
# Prediction for 24817 user_id for item_id 85 is 1.6467885518587992
# Prediction for 24817 user_id for item_id 86 is 1.0027292351648351
# Prediction for 24817 user_id for item_id 87 is 1.5898160658758067
# Prediction for 24817 user_id for item_id 88 is 1.0957855235379073
# Prediction for 24817 user_id for item_id 89 is 1.344423197400324
# Prediction for 24817 user_id for item_id 90 is 1.1935005007376474
# Prediction for 24817 user_id for item_id 91 is 0.891365483076243
# Prediction for 24817 user_id for item_id 92 is 0.47146117612585603
# Prediction for 24817 user_id for item_id 93 is 1.4563979911153635
# Prediction for 24817 user_id for item_id 94 is 1.0855238900941695
# Prediction for 24817 user_id for item_id 95 is 0.9720343610207581
# Prediction for 24817 user_id for item_id 96 is 1.5812028841792294
# Prediction for 24817 user_id for item_id 97 is 0.9418229547195649
# Prediction for 24817 user_id for item_id 98 is 1.4639417966416974
# Prediction for 24817 user_id for item_id 99 is 1.1651611537221473
# Prediction for 24818 user_id for item_id 0 is 0.8956671365617532
# Prediction for 24818 user_id for item_id 1 is 1.3178145420551988
# Prediction for 24818 user_id for item_id 2 is 1.6561012076394463
# Prediction for 24818 user_id for item_id 3 is 1.2901620346255978
# Prediction for 24818 user_id for item_id 5 is 1.3883464734197826
# Prediction for 24818 user_id for item_id 8 is 1.4685324126228083
# Prediction for 24818 user_id for item_id 9 is 0.8418934805261693
# Prediction for 24818 user_id for item_id 10 is 1.2417623975092051
# Prediction for 24818 user_id for item_id 11 is 0.8294160842625237
# Prediction for 24818 user_id for item_id 13 is 1.3014724800256265
# Prediction for 24818 user_id for item_id 21 is 1.4247715698873447
# Prediction for 24818 user_id for item_id 22 is 1.3883490090882544
# Prediction for 24818 user_id for item_id 23 is 0.8804055097766372
# Prediction for 24818 user_id for item_id 24 is 0.3807366566314281
# Prediction for 24818 user_id for item_id 25 is 0.825354214991919
# Prediction for 24818 user_id for item_id 28 is 1.1574256618167984
# Prediction for 24818 user_id for item_id 29 is 1.5209617097360273
# Prediction for 24818 user_id for item_id 30 is 1.0740488827375716
# Prediction for 24818 user_id for item_id 32 is 1.3652858774922214
# Prediction for 24818 user_id for item_id 36 is 1.4629956692131945
# Prediction for 24818 user_id for item_id 37 is 0.7049816554710675
# Prediction for 24818 user_id for item_id 38 is 1.3635427054574545
# Prediction for 24818 user_id for item_id 40 is 1.4906191975145118
# Prediction for 24818 user_id for item_id 43 is 1.4357826297766216
# Prediction for 24818 user_id for item_id 44 is 0.7605433221261827
# Prediction for 24818 user_id for item_id 45 is 0.9552945143386734
# Prediction for 24818 user_id for item_id 50 is 0.9198845388380162
# Prediction for 24818 user_id for item_id 51 is 1.0716199337914365
# Prediction for 24818 user_id for item_id 54 is 1.2624588055616122
# Prediction for 24818 user_id for item_id 56 is 1.4672204453046003
# Prediction for 24818 user_id for item_id 58 is 1.7609094538406886
# Prediction for 24818 user_id for item_id 59 is 1.5692602631598023
# Prediction for 24818 user_id for item_id 62 is 0.5976615923528594
# Prediction for 24818 user_id for item_id 63 is 1.2058543435489337
# Prediction for 24818 user_id for item_id 66 is 1.6248801586198338
# Prediction for 24818 user_id for item_id 70 is 1.6446740302467318
# Prediction for 24818 user_id for item_id 71 is 0.9256503809076517
# Prediction for 24818 user_id for item_id 72 is 0.9507643542767885
# Prediction for 24818 user_id for item_id 73 is 0.9938823549959973
# Prediction for 24818 user_id for item_id 74 is 1.6021941328632217
# Prediction for 24818 user_id for item_id 75 is 1.6075659506510425
# Prediction for 24818 user_id for item_id 76 is 0.9832714928583466
# Prediction for 24818 user_id for item_id 77 is 1.1275048325057393
# Prediction for 24818 user_id for item_id 78 is 1.3815304466353526
# Prediction for 24818 user_id for item_id 79 is 0.22757615053863522
# Prediction for 24818 user_id for item_id 80 is 1.071156253070337
# Prediction for 24818 user_id for item_id 82 is 0.7152111323656887
# Prediction for 24818 user_id for item_id 83 is 1.3375921701353444
# Prediction for 24818 user_id for item_id 84 is 1.41603698049965
# Prediction for 24818 user_id for item_id 85 is 1.475233160677619
# Prediction for 24818 user_id for item_id 86 is 0.8757516639039865
# Prediction for 24818 user_id for item_id 87 is 1.2970032639150022
# Prediction for 24818 user_id for item_id 88 is 0.9927314710840839
# Prediction for 24818 user_id for item_id 89 is 1.4797447549304497
# Prediction for 24818 user_id for item_id 90 is 1.10370653217102
# Prediction for 24818 user_id for item_id 91 is 0.9264468196385661
# Prediction for 24818 user_id for item_id 92 is 0.47001743336433455
# Prediction for 24818 user_id for item_id 93 is 1.2997354463215551
# Prediction for 24818 user_id for item_id 94 is 1.1203779891835193
# Prediction for 24818 user_id for item_id 95 is 0.7548075245488058
# Prediction for 24818 user_id for item_id 97 is 1.10295197395073
# Prediction for 24818 user_id for item_id 98 is 1.5546921268729157
# Prediction for 24818 user_id for item_id 99 is 0.930219244927795
# Prediction for 24821 user_id for item_id 0 is 0.8616322511052891
# Prediction for 24821 user_id for item_id 2 is 1.1942695540688804
# Prediction for 24821 user_id for item_id 3 is 0.8346598689965145
# Prediction for 24821 user_id for item_id 8 is 0.7577772386710296
# Prediction for 24821 user_id for item_id 23 is 0.7122945821597351
# Prediction for 24821 user_id for item_id 29 is 0.9845337238047783
# Prediction for 24821 user_id for item_id 32 is 0.6250421773330223
# Prediction for 24821 user_id for item_id 36 is 0.8041113296502578
# Prediction for 24821 user_id for item_id 37 is 0.5857500984537372
# Prediction for 24821 user_id for item_id 40 is 0.9460817120311261
# Prediction for 24821 user_id for item_id 42 is 0.7918135733675357
# Prediction for 24821 user_id for item_id 43 is 0.8267383683651517
# Prediction for 24821 user_id for item_id 54 is 0.649277086898342
# Prediction for 24821 user_id for item_id 56 is 1.0844131982795724
# Prediction for 24821 user_id for item_id 57 is 0.5857616752980255
# Prediction for 24821 user_id for item_id 58 is 1.1341347277521048
# Prediction for 24821 user_id for item_id 59 is 1.025738688258652
# Prediction for 24821 user_id for item_id 63 is 0.6826600436590458
# Prediction for 24821 user_id for item_id 66 is 0.9338464298187599
# Prediction for 24821 user_id for item_id 69 is 0.8143605563925288
# Prediction for 24821 user_id for item_id 70 is 0.9319964118360428
# Prediction for 24821 user_id for item_id 71 is 0.4543148404520627
# Prediction for 24821 user_id for item_id 72 is 0.8370117308473375
# Prediction for 24821 user_id for item_id 73 is 0.5622386209607854
# Prediction for 24821 user_id for item_id 74 is 1.1273727612077054
# Prediction for 24821 user_id for item_id 75 is 1.1447945877891037
# Prediction for 24821 user_id for item_id 76 is 0.7987700227596465
# Prediction for 24821 user_id for item_id 77 is 0.9049925425027922
# Prediction for 24821 user_id for item_id 78 is 1.1008956481369991
# Prediction for 24821 user_id for item_id 79 is 0.12433426287107265
# Prediction for 24821 user_id for item_id 80 is 0.530258102224158
# Prediction for 24821 user_id for item_id 81 is 0.24593410799106602
# Prediction for 24821 user_id for item_id 82 is 0.433797220845765
# Prediction for 24821 user_id for item_id 83 is 0.5433270360592065
# Prediction for 24821 user_id for item_id 84 is 1.0363820646436566
# Prediction for 24821 user_id for item_id 85 is 0.9907988027844834
# Prediction for 24821 user_id for item_id 86 is 0.4435604484518621
# Prediction for 24821 user_id for item_id 87 is 0.767386357369355
# Prediction for 24821 user_id for item_id 88 is 0.5552534816415926
# Prediction for 24821 user_id for item_id 89 is 0.9470480249736551
# Prediction for 24821 user_id for item_id 90 is 0.6932925743746207
# Prediction for 24821 user_id for item_id 91 is 0.5411791875393045
# Prediction for 24821 user_id for item_id 92 is 0.2405835274330165
# Prediction for 24821 user_id for item_id 93 is 0.9045039191611488
# Prediction for 24821 user_id for item_id 94 is 0.7560967763366803
# Prediction for 24821 user_id for item_id 95 is 0.6370795713653625
# Prediction for 24821 user_id for item_id 96 is 0.8733642847636243
# Prediction for 24821 user_id for item_id 97 is 0.682560814245058
# Prediction for 24821 user_id for item_id 98 is 0.7256176557554518
# Prediction for 24821 user_id for item_id 99 is 0.6348549101891061
# Prediction for 24822 user_id for item_id 0 is 1.0135797146693704
# Prediction for 24822 user_id for item_id 1 is 0.7987440472418443
# Prediction for 24822 user_id for item_id 2 is 1.3113769654161698
# Prediction for 24822 user_id for item_id 3 is 1.0921332316606118
# Prediction for 24822 user_id for item_id 5 is 0.8235691772581615
# Prediction for 24822 user_id for item_id 8 is 0.7717928724831403
# Prediction for 24822 user_id for item_id 9 is 0.4748902222542711
# Prediction for 24822 user_id for item_id 10 is 0.8899362823150795
# Prediction for 24822 user_id for item_id 11 is 0.711611944566162
# Prediction for 24822 user_id for item_id 13 is 1.0110467997012957
# Prediction for 24822 user_id for item_id 21 is 0.7236175305634972
# Prediction for 24822 user_id for item_id 23 is 0.8174437201981315
# Prediction for 24822 user_id for item_id 24 is 0.28345645712318
# Prediction for 24822 user_id for item_id 29 is 1.2317994257265574
# Prediction for 24822 user_id for item_id 32 is 0.6378428179411418
# Prediction for 24822 user_id for item_id 36 is 1.0642706766276562
# Prediction for 24822 user_id for item_id 39 is 0.3112639071975921
# Prediction for 24822 user_id for item_id 40 is 1.2429530512921794
# Prediction for 24822 user_id for item_id 42 is 0.99504860753994
# Prediction for 24822 user_id for item_id 43 is 1.0124897058068225
# Prediction for 24822 user_id for item_id 50 is 1.0580811577034634
# Prediction for 24822 user_id for item_id 51 is 0.7057760236232634
# Prediction for 24822 user_id for item_id 54 is 0.6361104687565953
# Prediction for 24822 user_id for item_id 56 is 1.0657550721183977
# Prediction for 24822 user_id for item_id 57 is 0.682696392217216
# Prediction for 24822 user_id for item_id 58 is 1.3011138007771856
# Prediction for 24822 user_id for item_id 59 is 1.2519008889744099
# Prediction for 24822 user_id for item_id 62 is 0.5877220149399833
# Prediction for 24822 user_id for item_id 63 is 0.8196634644550572
# Prediction for 24822 user_id for item_id 66 is 1.0896769950342742
# Prediction for 24822 user_id for item_id 69 is 0.8145044614828848
# Prediction for 24822 user_id for item_id 70 is 1.2247681560987886
# Prediction for 24822 user_id for item_id 71 is 0.363096487328251
# Prediction for 24822 user_id for item_id 72 is 0.942412053640404
# Prediction for 24822 user_id for item_id 73 is 0.6102336174843648
# Prediction for 24822 user_id for item_id 75 is 1.1848212045540165
# Prediction for 24822 user_id for item_id 76 is 1.097925265677178
# Prediction for 24822 user_id for item_id 77 is 1.0378878543778116
# Prediction for 24822 user_id for item_id 78 is 1.2910042043187295
# Prediction for 24822 user_id for item_id 79 is 0.14007992082266854
# Prediction for 24822 user_id for item_id 80 is 0.714016102248077
# Prediction for 24822 user_id for item_id 81 is 0.3951293309666632
# Prediction for 24822 user_id for item_id 82 is 0.5330666468513259
# Prediction for 24822 user_id for item_id 83 is 0.758068258486802
# Prediction for 24822 user_id for item_id 84 is 1.0714583671925113
# Prediction for 24822 user_id for item_id 85 is 1.0717791659822313
# Prediction for 24822 user_id for item_id 86 is 0.572580024159045
# Prediction for 24822 user_id for item_id 87 is 0.8585205592673644
# Prediction for 24822 user_id for item_id 88 is 0.5555860817607241
# Prediction for 24822 user_id for item_id 89 is 1.0880252744833585
# Prediction for 24822 user_id for item_id 90 is 0.7188435786118855
# Prediction for 24822 user_id for item_id 91 is 0.5813560747161142
# Prediction for 24822 user_id for item_id 92 is 0.3141657195815652
# Prediction for 24822 user_id for item_id 93 is 1.2545111583554411
# Prediction for 24822 user_id for item_id 94 is 0.8168136924426006
# Prediction for 24822 user_id for item_id 95 is 0.7603483958008211
# Prediction for 24822 user_id for item_id 96 is 0.9424759489655689
# Prediction for 24822 user_id for item_id 97 is 0.7052783166468097
# Prediction for 24822 user_id for item_id 98 is 0.8627657198601842
# Prediction for 24822 user_id for item_id 99 is 0.6819997451900267
# Prediction for 24823 user_id for item_id 57 is 1.2610192345452482
# Prediction for 24823 user_id for item_id 70 is 2.5982578056379046
# Prediction for 24823 user_id for item_id 71 is 1.4548794400451512
# Prediction for 24823 user_id for item_id 72 is 1.5784432821512209
# Prediction for 24823 user_id for item_id 73 is 1.5388342595557583
# Prediction for 24823 user_id for item_id 74 is 2.574727638431923
# Prediction for 24823 user_id for item_id 75 is 2.5974725310622353
# Prediction for 24823 user_id for item_id 76 is 1.601913630232536
# Prediction for 24823 user_id for item_id 77 is 1.818809506636129
# Prediction for 24823 user_id for item_id 78 is 2.2394312863475196
# Prediction for 24823 user_id for item_id 79 is 0.3527942022135415
# Prediction for 24823 user_id for item_id 80 is 1.6708961434385856
# Prediction for 24823 user_id for item_id 81 is 0.923705629675607
# Prediction for 24823 user_id for item_id 82 is 1.1444760804575518
# Prediction for 24823 user_id for item_id 83 is 2.0524906725049807
# Prediction for 24823 user_id for item_id 84 is 2.2945144540213214
# Prediction for 24823 user_id for item_id 85 is 2.35755631019948
# Prediction for 24823 user_id for item_id 86 is 1.3763133813726072
# Prediction for 24823 user_id for item_id 87 is 2.065700170883646
# Prediction for 24823 user_id for item_id 88 is 1.5657105732143295
# Prediction for 24823 user_id for item_id 89 is 2.3325634781476197
# Prediction for 24823 user_id for item_id 90 is 1.7522384740343169
# Prediction for 24823 user_id for item_id 91 is 1.455026117515951
# Prediction for 24823 user_id for item_id 92 is 0.7338851119818428
# Prediction for 24823 user_id for item_id 93 is 2.0839661943235
# Prediction for 24823 user_id for item_id 94 is 1.7781222903258675
# Prediction for 24823 user_id for item_id 95 is 1.2395841856445442
# Prediction for 24823 user_id for item_id 97 is 1.7295107112048584
# Prediction for 24823 user_id for item_id 98 is 2.4073042131673987
# Prediction for 24823 user_id for item_id 99 is 1.4983023946396237
# Prediction for 24825 user_id for item_id 0 is 1.3380062122586942
# Prediction for 24825 user_id for item_id 1 is 1.4983242490160742
# Prediction for 24825 user_id for item_id 2 is 2.247259166642336
# Prediction for 24825 user_id for item_id 3 is 1.537103756902891
# Prediction for 24825 user_id for item_id 8 is 1.7998920732424584
# Prediction for 24825 user_id for item_id 23 is 1.2330389302037665
# Prediction for 24825 user_id for item_id 36 is 1.6442412577067438
# Prediction for 24825 user_id for item_id 42 is 1.6494872650041925
# Prediction for 24825 user_id for item_id 43 is 1.7011621729953148
# Prediction for 24825 user_id for item_id 56 is 2.1001197351827052
# Prediction for 24825 user_id for item_id 57 is 1.0257758971336048
# Prediction for 24825 user_id for item_id 59 is 1.9447575743853978
# Prediction for 24825 user_id for item_id 70 is 1.8736878847286083
# Prediction for 24825 user_id for item_id 71 is 1.1805206451802095
# Prediction for 24825 user_id for item_id 72 is 1.3907395909837597
# Prediction for 24825 user_id for item_id 74 is 2.1210306179186516
# Prediction for 24825 user_id for item_id 75 is 2.221895148854505
# Prediction for 24825 user_id for item_id 77 is 1.5853572478472306
# Prediction for 24825 user_id for item_id 78 is 1.9073013335032758
# Prediction for 24825 user_id for item_id 79 is 0.27725122329435253
# Prediction for 24825 user_id for item_id 80 is 1.1597844567727822
# Prediction for 24825 user_id for item_id 81 is 0.5826851186353453
# Prediction for 24825 user_id for item_id 82 is 0.8564305742706801
# Prediction for 24825 user_id for item_id 83 is 1.3581752938661333
# Prediction for 24825 user_id for item_id 85 is 1.9600348625503319
# Prediction for 24825 user_id for item_id 86 is 0.9683948937059605
# Prediction for 24825 user_id for item_id 87 is 1.6063265518798606
# Prediction for 24825 user_id for item_id 88 is 1.2582636211191873
# Prediction for 24825 user_id for item_id 89 is 1.8922768572481303
# Prediction for 24825 user_id for item_id 90 is 1.4507226821748476
# Prediction for 24825 user_id for item_id 91 is 1.1713213398381332
# Prediction for 24825 user_id for item_id 92 is 0.5218977341283759
# Prediction for 24825 user_id for item_id 93 is 1.5445980517863027
# Prediction for 24825 user_id for item_id 94 is 1.500226123857292
# Prediction for 24825 user_id for item_id 95 is 1.054235881175679
# Prediction for 24825 user_id for item_id 96 is 1.8143360569472091
# Prediction for 24825 user_id for item_id 97 is 1.4542088891811902
# Prediction for 24825 user_id for item_id 98 is 1.7468303642694272
# Prediction for 24825 user_id for item_id 99 is 1.242205902006571
# Prediction for 24826 user_id for item_id 0 is 0.5937559568132371
# Prediction for 24826 user_id for item_id 1 is 0.8718052436023901
# Prediction for 24826 user_id for item_id 2 is 1.1810796811172626
# Prediction for 24826 user_id for item_id 3 is 0.8555281552457233
# Prediction for 24826 user_id for item_id 5 is 1.3474731451242623
# Prediction for 24826 user_id for item_id 8 is 1.1885351071928376
# Prediction for 24826 user_id for item_id 9 is 0.6883805898466733
# Prediction for 24826 user_id for item_id 10 is 1.2253846263922021
# Prediction for 24826 user_id for item_id 11 is 0.5266744631532432
# Prediction for 24826 user_id for item_id 13 is 1.1313840234517871
# Prediction for 24826 user_id for item_id 21 is 1.1905697083178655
# Prediction for 24826 user_id for item_id 22 is 0.8412292030704185
# Prediction for 24826 user_id for item_id 23 is 0.6663423891386722
# Prediction for 24826 user_id for item_id 24 is 0.36398736566246187
# Prediction for 24826 user_id for item_id 25 is 0.94433591166234
# Prediction for 24826 user_id for item_id 29 is 0.916966510496428
# Prediction for 24826 user_id for item_id 32 is 1.2598854299530888
# Prediction for 24826 user_id for item_id 33 is 0.07967594434435908
# Prediction for 24826 user_id for item_id 36 is 1.0446055922696937
# Prediction for 24826 user_id for item_id 38 is 1.0165413669963232
# Prediction for 24826 user_id for item_id 39 is 0.6511724114313862
# Prediction for 24826 user_id for item_id 40 is 1.251979359073684
# Prediction for 24826 user_id for item_id 42 is 1.168019772974977
# Prediction for 24826 user_id for item_id 43 is 1.0585498019587327
# Prediction for 24826 user_id for item_id 44 is 0.7477165552265829
# Prediction for 24826 user_id for item_id 46 is 0.863392115804394
# Prediction for 24826 user_id for item_id 50 is 0.7160218047018816
# Prediction for 24826 user_id for item_id 51 is 1.0033658100551215
# Prediction for 24826 user_id for item_id 54 is 1.0052817380794308
# Prediction for 24826 user_id for item_id 57 is 0.33803462789090666
# Prediction for 24826 user_id for item_id 58 is 1.3552743894850887
# Prediction for 24826 user_id for item_id 62 is 0.3725204132463674
# Prediction for 24826 user_id for item_id 63 is 1.1722885129710885
# Prediction for 24826 user_id for item_id 66 is 1.3108437035414755
# Prediction for 24826 user_id for item_id 69 is 0.9854047996999692
# Prediction for 24826 user_id for item_id 71 is 0.5758188482265257
# Prediction for 24826 user_id for item_id 72 is 0.575572281184087
# Prediction for 24826 user_id for item_id 73 is 1.0903999722194098
# Prediction for 24826 user_id for item_id 74 is 1.2273998714138927
# Prediction for 24826 user_id for item_id 75 is 1.1033594675719305
# Prediction for 24826 user_id for item_id 76 is 0.7739913635392552
# Prediction for 24826 user_id for item_id 77 is 1.0794798801189327
# Prediction for 24826 user_id for item_id 78 is 1.1714393736723228
# Prediction for 24826 user_id for item_id 79 is 0.23255997108038423
# Prediction for 24826 user_id for item_id 80 is 0.8211341924262001
# Prediction for 24826 user_id for item_id 81 is 0.6098247864173347
# Prediction for 24826 user_id for item_id 82 is 0.41923005160264676
# Prediction for 24826 user_id for item_id 83 is 1.1128636535285297
# Prediction for 24826 user_id for item_id 85 is 1.1620307242083399
# Prediction for 24826 user_id for item_id 86 is 0.5770355603080514
# Prediction for 24826 user_id for item_id 87 is 0.8273190865358728
# Prediction for 24826 user_id for item_id 88 is 0.7324434650075213
# Prediction for 24826 user_id for item_id 89 is 1.4220445358694633
# Prediction for 24826 user_id for item_id 90 is 0.8799225363569334
# Prediction for 24826 user_id for item_id 91 is 0.8170309961452082
# Prediction for 24826 user_id for item_id 92 is 0.3732733255568913
# Prediction for 24826 user_id for item_id 93 is 1.0185264976604895
# Prediction for 24826 user_id for item_id 94 is 1.0391534842178431
# Prediction for 24826 user_id for item_id 95 is 0.5435691977064555
# Prediction for 24826 user_id for item_id 96 is 1.066344611767473
# Prediction for 24826 user_id for item_id 97 is 1.1082230575193033
# Prediction for 24826 user_id for item_id 98 is 1.2903545679847304
# Prediction for 24826 user_id for item_id 99 is 0.6202633450113221
# Prediction for 24827 user_id for item_id 0 is 0.4866277481153235
# Prediction for 24827 user_id for item_id 1 is 1.4780192075353797
# Prediction for 24827 user_id for item_id 2 is 1.2771576174879995
# Prediction for 24827 user_id for item_id 3 is 1.3029689105431352
# Prediction for 24827 user_id for item_id 8 is 1.4216238256484588
# Prediction for 24827 user_id for item_id 9 is 0.6650194975012766
# Prediction for 24827 user_id for item_id 23 is 0.5971349794662486
# Prediction for 24827 user_id for item_id 29 is 1.5151811220988372
# Prediction for 24827 user_id for item_id 32 is 1.3790191176585058
# Prediction for 24827 user_id for item_id 36 is 1.6212593724627087
# Prediction for 24827 user_id for item_id 42 is 1.4560362675510032
# Prediction for 24827 user_id for item_id 43 is 1.4634680161024483
# Prediction for 24827 user_id for item_id 50 is 0.4583063181655375
# Prediction for 24827 user_id for item_id 54 is 1.207696847031568
# Prediction for 24827 user_id for item_id 56 is 1.0272731381068463
# Prediction for 24827 user_id for item_id 57 is 0.6532699888435312
# Prediction for 24827 user_id for item_id 63 is 1.130651210792409
# Prediction for 24827 user_id for item_id 66 is 1.5700537587645569
# Prediction for 24827 user_id for item_id 69 is 0.925439938079496
# Prediction for 24827 user_id for item_id 71 is 0.896462004460135
# Prediction for 24827 user_id for item_id 72 is 0.5923521811939075
# Prediction for 24827 user_id for item_id 73 is 0.830304045395894
# Prediction for 24827 user_id for item_id 74 is 1.2849620870389848
# Prediction for 24827 user_id for item_id 75 is 1.2072136622919105
# Prediction for 24827 user_id for item_id 76 is 0.8186982172455493
# Prediction for 24827 user_id for item_id 77 is 0.6954813650382835
# Prediction for 24827 user_id for item_id 78 is 0.94027913818614
# Prediction for 24827 user_id for item_id 79 is 0.2065030560667053
# Prediction for 24827 user_id for item_id 80 is 1.2430628831166906
# Prediction for 24827 user_id for item_id 81 is 0.7738754124015927
# Prediction for 24827 user_id for item_id 83 is 1.674370483293911
# Prediction for 24827 user_id for item_id 84 is 1.0251137244384847
# Prediction for 24827 user_id for item_id 85 is 1.1803425079904586
# Prediction for 24827 user_id for item_id 86 is 1.015264626624115
# Prediction for 24827 user_id for item_id 87 is 1.267375582866631
# Prediction for 24827 user_id for item_id 89 is 1.2158206091595969
# Prediction for 24827 user_id for item_id 90 is 0.9142422425228692
# Prediction for 24827 user_id for item_id 91 is 0.8144696374703406
# Prediction for 24827 user_id for item_id 92 is 0.5235056985176079
# Prediction for 24827 user_id for item_id 93 is 1.2531353890770651
# Prediction for 24827 user_id for item_id 94 is 0.8368244249895043
# Prediction for 24827 user_id for item_id 95 is 0.5150207685050141
# Prediction for 24827 user_id for item_id 96 is 1.2446999646344332
# Prediction for 24827 user_id for item_id 97 is 0.8466865626556622
# Prediction for 24827 user_id for item_id 98 is 1.7129379138115932
# Prediction for 24827 user_id for item_id 99 is 0.7652446378112111
# Prediction for 24828 user_id for item_id 0 is 0.8160599915602683
# Prediction for 24828 user_id for item_id 1 is 0.9392336517980577
# Prediction for 24828 user_id for item_id 2 is 1.3372752515841995
# Prediction for 24828 user_id for item_id 3 is 1.0104715429734445
# Prediction for 24828 user_id for item_id 5 is 1.0411493761383015
# Prediction for 24828 user_id for item_id 8 is 1.0714519944703673
# Prediction for 24828 user_id for item_id 9 is 0.64241923752748
# Prediction for 24828 user_id for item_id 10 is 0.9893890477499069
# Prediction for 24828 user_id for item_id 11 is 0.6849458759056513
# Prediction for 24828 user_id for item_id 13 is 1.041068305510305
# Prediction for 24828 user_id for item_id 21 is 1.03135992496154
# Prediction for 24828 user_id for item_id 22 is 1.0770913421095574
# Prediction for 24828 user_id for item_id 23 is 0.7534776116492365
# Prediction for 24828 user_id for item_id 24 is 0.29549650339805805
# Prediction for 24828 user_id for item_id 25 is 0.6829371943207085
# Prediction for 24828 user_id for item_id 29 is 1.1718457493201797
# Prediction for 24828 user_id for item_id 32 is 0.985856656291614
# Prediction for 24828 user_id for item_id 36 is 1.0940846502080832
# Prediction for 24828 user_id for item_id 38 is 1.0609257488622286
# Prediction for 24828 user_id for item_id 39 is 0.4879375242901013
# Prediction for 24828 user_id for item_id 40 is 1.1986641714704915
# Prediction for 24828 user_id for item_id 44 is 0.5973482952996285
# Prediction for 24828 user_id for item_id 46 is 0.98248938856205
# Prediction for 24828 user_id for item_id 50 is 0.8583963422126288
# Prediction for 24828 user_id for item_id 51 is 0.868239084493967
# Prediction for 24828 user_id for item_id 54 is 0.9150289445227638
# Prediction for 24828 user_id for item_id 57 is 0.6060263104257988
# Prediction for 24828 user_id for item_id 58 is 1.3846756286332607
# Prediction for 24828 user_id for item_id 59 is 1.2245839585115637
# Prediction for 24828 user_id for item_id 63 is 0.9475545283614183
# Prediction for 24828 user_id for item_id 66 is 1.2398699802238455
# Prediction for 24828 user_id for item_id 69 is 0.967949130667058
# Prediction for 24828 user_id for item_id 70 is 1.2433864950589977
# Prediction for 24828 user_id for item_id 71 is 0.6292112829458452
# Prediction for 24828 user_id for item_id 72 is 0.8197963365927482
# Prediction for 24828 user_id for item_id 73 is 0.7920712044766162
# Prediction for 24828 user_id for item_id 74 is 1.2992532375536154
# Prediction for 24828 user_id for item_id 75 is 1.2776964093645742
# Prediction for 24828 user_id for item_id 77 is 0.9951009170881437
# Prediction for 24828 user_id for item_id 78 is 1.1966281119662063
# Prediction for 24828 user_id for item_id 79 is 0.1775243226991397
# Prediction for 24828 user_id for item_id 80 is 0.7842728432080479
# Prediction for 24828 user_id for item_id 81 is 0.4482756606137225
# Prediction for 24828 user_id for item_id 82 is 0.5352880752872607
# Prediction for 24828 user_id for item_id 83 is 0.9411736378939762
# Prediction for 24828 user_id for item_id 84 is 1.1367105214526023
# Prediction for 24828 user_id for item_id 85 is 1.1744906791340741
# Prediction for 24828 user_id for item_id 86 is 0.629168100690068
# Prediction for 24828 user_id for item_id 88 is 0.7307412754303425
# Prediction for 24828 user_id for item_id 89 is 1.202916735292082
# Prediction for 24828 user_id for item_id 90 is 0.8564722982617193
# Prediction for 24828 user_id for item_id 91 is 0.7155451975383873
# Prediction for 24828 user_id for item_id 92 is 0.3485736283396175
# Prediction for 24828 user_id for item_id 93 is 1.077422331938389
# Prediction for 24828 user_id for item_id 94 is 0.9165011661449254
# Prediction for 24828 user_id for item_id 95 is 0.6564921912921798
# Prediction for 24828 user_id for item_id 96 is 1.08573206137653
# Prediction for 24828 user_id for item_id 97 is 0.8850658368943353
# Prediction for 24828 user_id for item_id 98 is 1.1204348427221749
# Prediction for 24828 user_id for item_id 99 is 0.7277782404407146
# Prediction for 24830 user_id for item_id 8 is 1.1675154733702302
# Prediction for 24830 user_id for item_id 23 is 0.9858519220639007
# Prediction for 24830 user_id for item_id 36 is 1.4126785657732683
# Prediction for 24830 user_id for item_id 43 is 1.3512917026942433
# Prediction for 24830 user_id for item_id 56 is 1.200550180633662
# Prediction for 24830 user_id for item_id 57 is 0.6819627426144715
# Prediction for 24830 user_id for item_id 66 is 1.534263161139615
# Prediction for 24830 user_id for item_id 70 is 1.6174986987230215
# Prediction for 24830 user_id for item_id 71 is 0.48288097844830696
# Prediction for 24830 user_id for item_id 73 is 1.0605211892839048
# Prediction for 24830 user_id for item_id 74 is 1.6316478605591138
# Prediction for 24830 user_id for item_id 75 is 1.421020669035998
# Prediction for 24830 user_id for item_id 76 is 1.346009911866003
# Prediction for 24830 user_id for item_id 78 is 1.6465119140469895
# Prediction for 24830 user_id for item_id 79 is 0.23421919006340156
# Prediction for 24830 user_id for item_id 80 is 1.0178862837381089
# Prediction for 24830 user_id for item_id 81 is 0.6840239051542877
# Prediction for 24830 user_id for item_id 82 is 0.628147387143239
# Prediction for 24830 user_id for item_id 83 is 1.2189350657196585
# Prediction for 24830 user_id for item_id 84 is 1.2711514036185774
# Prediction for 24830 user_id for item_id 85 is 1.4096335780014968
# Prediction for 24830 user_id for item_id 86 is 0.7526917277307501
# Prediction for 24830 user_id for item_id 87 is 1.0586835104864474
# Prediction for 24830 user_id for item_id 88 is 0.7648327110670063
# Prediction for 24830 user_id for item_id 89 is 1.6177977729219732
# Prediction for 24830 user_id for item_id 90 is 0.9817874273632666
# Prediction for 24830 user_id for item_id 91 is 0.8668016778196166
# Prediction for 24830 user_id for item_id 92 is 0.4524262715049706
# Prediction for 24830 user_id for item_id 93 is 1.6048773755279038
# Prediction for 24830 user_id for item_id 94 is 1.1738741064223557
# Prediction for 24830 user_id for item_id 95 is 0.8880900346437394
# Prediction for 24830 user_id for item_id 96 is 1.2517530341667733
# Prediction for 24830 user_id for item_id 97 is 1.1181633455719762
# Prediction for 24830 user_id for item_id 98 is 1.3485105651378286
# Prediction for 24830 user_id for item_id 99 is 0.8188740581579772
# Prediction for 24831 user_id for item_id 70 is 1.5094947800938092
# Prediction for 24831 user_id for item_id 71 is 0.870772567339643
# Prediction for 24831 user_id for item_id 72 is 0.9102932768632959
# Prediction for 24831 user_id for item_id 73 is 0.7296096850847895
# Prediction for 24831 user_id for item_id 74 is 1.4209106732961139
# Prediction for 24831 user_id for item_id 75 is 1.473808979640584
# Prediction for 24831 user_id for item_id 76 is 0.8778279148336743
# Prediction for 24831 user_id for item_id 77 is 0.9003861045930337
# Prediction for 24831 user_id for item_id 78 is 1.1751567994366952
# Prediction for 24831 user_id for item_id 79 is 0.17543334709737854
# Prediction for 24831 user_id for item_id 80 is 0.962046210043469
# Prediction for 24831 user_id for item_id 81 is 0.4853262056960495
# Prediction for 24831 user_id for item_id 82 is 0.6975277534167328
# Prediction for 24831 user_id for item_id 83 is 1.1628030966963208
# Prediction for 24831 user_id for item_id 84 is 1.2987387819868912
# Prediction for 24831 user_id for item_id 85 is 1.2892931336404738
# Prediction for 24831 user_id for item_id 86 is 0.8276621843086999
# Prediction for 24831 user_id for item_id 87 is 1.2268390783554257
# Prediction for 24831 user_id for item_id 89 is 1.1820688996220685
# Prediction for 24831 user_id for item_id 90 is 0.9578326313648855
# Prediction for 24831 user_id for item_id 91 is 0.7706808320935292
# Prediction for 24831 user_id for item_id 92 is 0.41538822161781513
# Prediction for 24831 user_id for item_id 93 is 1.1620885611291996
# Prediction for 24831 user_id for item_id 94 is 0.9072128545820979
# Prediction for 24831 user_id for item_id 95 is 0.6871154564353116
# Prediction for 24831 user_id for item_id 96 is 1.2576267363282416
# Prediction for 24831 user_id for item_id 97 is 0.8522597733940324
# Prediction for 24831 user_id for item_id 98 is 1.3408164176346897
# Prediction for 24831 user_id for item_id 99 is 0.8639335535673517
# Prediction for 24832 user_id for item_id 70 is 1.3147260742135838
# Prediction for 24832 user_id for item_id 71 is 1.1762328647641824
# Prediction for 24832 user_id for item_id 72 is 0.9157411005998093
# Prediction for 24832 user_id for item_id 73 is 0.8049418403812174
# Prediction for 24832 user_id for item_id 74 is 1.4441531486811927
# Prediction for 24832 user_id for item_id 75 is 1.6916558434659212
# Prediction for 24832 user_id for item_id 76 is 0.5664856681902538
# Prediction for 24832 user_id for item_id 77 is 0.8747701676609122
# Prediction for 24832 user_id for item_id 78 is 1.1056133716581822
# Prediction for 24832 user_id for item_id 79 is 0.1855448089695231
# Prediction for 24832 user_id for item_id 80 is 0.8417272769816423
# Prediction for 24832 user_id for item_id 81 is 0.336656481957321
# Prediction for 24832 user_id for item_id 82 is 0.6631056849923954
# Prediction for 24832 user_id for item_id 83 is 1.0286505721937107
# Prediction for 24832 user_id for item_id 84 is 1.4920021366437672
# Prediction for 24832 user_id for item_id 85 is 1.4094912704749372
# Prediction for 24832 user_id for item_id 86 is 0.7677968005204991
# Prediction for 24832 user_id for item_id 87 is 1.3046622095347298
# Prediction for 24832 user_id for item_id 88 is 1.0548083609774686
# Prediction for 24832 user_id for item_id 89 is 1.1939314908825758
# Prediction for 24832 user_id for item_id 90 is 1.1022904699058635
# Prediction for 24832 user_id for item_id 92 is 0.3737299427851745
# Prediction for 24832 user_id for item_id 93 is 0.8189110220009733
# Prediction for 24832 user_id for item_id 94 is 0.9934712151236763
# Prediction for 24832 user_id for item_id 95 is 0.6229488000337109
# Prediction for 24832 user_id for item_id 96 is 1.385744669125001
# Prediction for 24832 user_id for item_id 97 is 0.9914324771333142
# Prediction for 24832 user_id for item_id 98 is 1.370023041967781
# Prediction for 24832 user_id for item_id 99 is 0.9510174730959028
# Prediction for 24833 user_id for item_id 70 is 1.186570423403638
# Prediction for 24833 user_id for item_id 71 is 0.31073687306008474
# Prediction for 24833 user_id for item_id 72 is 0.8918939495770445
# Prediction for 24833 user_id for item_id 73 is 0.5190505813162074
# Prediction for 24833 user_id for item_id 74 is 1.1921179326350533
# Prediction for 24833 user_id for item_id 75 is 1.084491861720866
# ...
# Prediction for 24976 user_id for item_id 74 is 1.5909593706964544
# Prediction for 24976 user_id for item_id 75 is 1.5470718286484828
# Prediction for 24976 user_id for item_id 76 is 1.2038649245452866
# Prediction for 24976 user_id for item_id 78 is 1.3393638760819089
# Prediction for 24976 user_id for item_id 79 is 0.17681533088168114
# Prediction for 24976 user_id for item_id 80 is 1.1880453442023036
# Prediction for 24976 user_id for item_id 81 is 0.6255544792929676
# Prediction for 24976 user_id for item_id 82 is 0.8547248387202111
# Prediction for 24976 user_id for item_id 83 is 1.4106863247988175
# Prediction for 24976 user_id for item_id 84 is 1.3614167791792076
# Prediction for 24976 user_id for item_id 85 is 1.3663506662976865
# Prediction for 24976 user_id for item_id 86 is 1.0165169204535593
# Prediction for 24976 user_id for item_id 87 is 1.3884706105499203
# Prediction for 24976 user_id for item_id 88 is 0.9022409569243052
# Prediction for 24976 user_id for item_id 89 is 1.252382727721654
# Prediction for 24976 user_id for item_id 90 is 0.9754263124941445
# Prediction for 24976 user_id for item_id 91 is 0.7861935502787771
# Prediction for 24976 user_id for item_id 92 is 0.5015143848998871
# Prediction for 24977 user_id for item_id 0 is 0.9207192246730458
# Prediction for 24977 user_id for item_id 1 is 0.8195316186444842
# Prediction for 24977 user_id for item_id 2 is 1.2969580164661858
# Prediction for 24977 user_id for item_id 3 is 0.9789502234692068
# Prediction for 24977 user_id for item_id 5 is 0.6459963506387429
# Prediction for 24977 user_id for item_id 8 is 0.8134240918567845
# Prediction for 24977 user_id for item_id 9 is 0.5236786767804823
# Prediction for 24977 user_id for item_id 11 is 0.7307047745514529
# Prediction for 24977 user_id for item_id 13 is 0.8361162708195978
# Prediction for 24977 user_id for item_id 21 is 0.7429872107426465
# Prediction for 24977 user_id for item_id 22 is 1.1018690592677884
# Prediction for 24977 user_id for item_id 23 is 0.745232756581233
# Prediction for 24977 user_id for item_id 24 is 0.19825214434827235
# Prediction for 24977 user_id for item_id 25 is 0.4114745516898568
# Prediction for 24977 user_id for item_id 27 is 0.8728805252518627
# Prediction for 24977 user_id for item_id 29 is 1.1878847994500155
# Prediction for 24977 user_id for item_id 32 is 0.6179818071092992
# Prediction for 24977 user_id for item_id 33 is 0.09680230992234189
# Prediction for 24977 user_id for item_id 36 is 0.9489903219115313
# Prediction for 24977 user_id for item_id 37 is 0.6596683113638723
# Prediction for 24977 user_id for item_id 38 is 0.946646782927312
# Prediction for 24977 user_id for item_id 39 is 0.31912342582849496
# Prediction for 24977 user_id for item_id 40 is 0.9972045447825797
# Prediction for 24977 user_id for item_id 42 is 0.8543674794287573
# Prediction for 24977 user_id for item_id 44 is 0.41645816396990426
# Prediction for 24977 user_id for item_id 46 is 0.9461106048074297
# Prediction for 24977 user_id for item_id 50 is 0.9069455036266401
# Prediction for 24977 user_id for item_id 51 is 0.672796301953462
# Prediction for 24977 user_id for item_id 54 is 0.7013349968005288
# Prediction for 24977 user_id for item_id 56 is 1.2134345632572634
# Prediction for 24977 user_id for item_id 57 is 0.7274488446956315
# Prediction for 24977 user_id for item_id 58 is 1.2226467213341952
# Prediction for 24977 user_id for item_id 59 is 1.1861744538909316
# Prediction for 24977 user_id for item_id 62 is 0.5877338990421097
# Prediction for 24977 user_id for item_id 63 is 0.6495672443703219
# Prediction for 24977 user_id for item_id 66 is 1.003767604497019
# Prediction for 24977 user_id for item_id 69 is 0.8381985537034892
# Prediction for 24977 user_id for item_id 71 is 0.5564199331531368
# Prediction for 24977 user_id for item_id 72 is 0.9269114149917006
# Prediction for 24977 user_id for item_id 74 is 1.1983767390531703
# Prediction for 24977 user_id for item_id 75 is 1.2556443532094888
# Prediction for 24977 user_id for item_id 76 is 0.8465734516414924
# Prediction for 24977 user_id for item_id 77 is 0.8467028204969737
# Prediction for 24977 user_id for item_id 78 is 1.101939490558441
# Prediction for 24977 user_id for item_id 79 is 0.11224307639816414
# Prediction for 24977 user_id for item_id 80 is 0.6179915025360727
# Prediction for 24977 user_id for item_id 81 is 0.24479655096939387
# Prediction for 24977 user_id for item_id 83 is 0.6275189707099043
# Prediction for 24977 user_id for item_id 84 is 1.1314630903243845
# Prediction for 24977 user_id for item_id 85 is 1.0395981428369994
# Prediction for 24977 user_id for item_id 86 is 0.5532644721440684
# Prediction for 24977 user_id for item_id 87 is 0.9137553247462162
# Prediction for 24977 user_id for item_id 88 is 0.6176870765509906
# Prediction for 24977 user_id for item_id 89 is 0.8955933465374522
# Prediction for 24977 user_id for item_id 90 is 0.7266846194493335
# Prediction for 24977 user_id for item_id 91 is 0.5420838656397836
# Prediction for 24977 user_id for item_id 92 is 0.2712661060790008
# Prediction for 24977 user_id for item_id 93 is 0.9836603000844709
# Prediction for 24977 user_id for item_id 94 is 0.7224703529703159
# Prediction for 24977 user_id for item_id 95 is 0.6787286051770823
# Prediction for 24977 user_id for item_id 96 is 0.949987162950398
# Prediction for 24977 user_id for item_id 97 is 0.6144724514830612
# Prediction for 24977 user_id for item_id 98 is 0.7970338496181483
# Prediction for 24977 user_id for item_id 99 is 0.7140781650181537
# Prediction for 24979 user_id for item_id 70 is 1.33460980344161
# Prediction for 24979 user_id for item_id 71 is 1.2716100400141057
# Prediction for 24979 user_id for item_id 72 is 0.7109765630761223
# Prediction for 24979 user_id for item_id 73 is 0.8106912360973184
# Prediction for 24979 user_id for item_id 74 is 1.3044294363498343
# Prediction for 24979 user_id for item_id 76 is 0.3774907795805649
# Prediction for 24979 user_id for item_id 77 is 0.6771785830096628
# Prediction for 24979 user_id for item_id 78 is 0.8749463561669024
# Prediction for 24979 user_id for item_id 79 is 0.19067188522067016
# Prediction for 24980 user_id for item_id 0 is 1.156634173224909
# Prediction for 24980 user_id for item_id 1 is 1.325511393729928
# Prediction for 24980 user_id for item_id 2 is 1.8130250794453862
# Prediction for 24980 user_id for item_id 3 is 1.4452282601442985
# Prediction for 24980 user_id for item_id 5 is 1.1711718176393857
# Prediction for 24980 user_id for item_id 8 is 1.3345253624808517
# Prediction for 24980 user_id for item_id 9 is 0.7908104684941692
# Prediction for 24980 user_id for item_id 10 is 1.1190149654011035
# Prediction for 24980 user_id for item_id 11 is 0.973041097041013
# Prediction for 24980 user_id for item_id 21 is 1.2593150494418428
# Prediction for 24980 user_id for item_id 22 is 1.575823628194988
# Prediction for 24980 user_id for item_id 23 is 1.0037918922786566
# Prediction for 24980 user_id for item_id 24 is 0.3468191712420504
# Prediction for 24980 user_id for item_id 29 is 1.73036129540596
# Prediction for 24980 user_id for item_id 32 is 1.1184710344003301
# Prediction for 24980 user_id for item_id 33 is 0.12265608208975855
# Prediction for 24980 user_id for item_id 36 is 1.5095118024067782
# Prediction for 24980 user_id for item_id 38 is 1.4157036058718058
# Prediction for 24980 user_id for item_id 39 is 0.48360239313220427
# Prediction for 24980 user_id for item_id 42 is 1.3771195847810118
# Prediction for 24980 user_id for item_id 43 is 1.4631438898597018
# Prediction for 24980 user_id for item_id 44 is 0.6440236030457351
# Prediction for 24980 user_id for item_id 51 is 0.994026209157381
# Prediction for 24980 user_id for item_id 54 is 1.145651293649102
# Prediction for 24980 user_id for item_id 56 is 1.644418738165517
# Prediction for 24980 user_id for item_id 57 is 0.974099278245276
# Prediction for 24980 user_id for item_id 58 is 1.8149401683878665
# Prediction for 24980 user_id for item_id 59 is 1.7326303088371318
# Prediction for 24980 user_id for item_id 62 is 0.7454455852295182
# Prediction for 24980 user_id for item_id 63 is 1.0759018071565023
# Prediction for 24980 user_id for item_id 66 is 1.580793152379453
# Prediction for 24980 user_id for item_id 69 is 1.2182137360254244
# Prediction for 24980 user_id for item_id 70 is 1.7073888274809812
# Prediction for 24980 user_id for item_id 72 is 1.1913356020587917
# Prediction for 24980 user_id for item_id 73 is 0.8033730243540895
# Prediction for 24980 user_id for item_id 74 is 1.7105437225382876
# Prediction for 24980 user_id for item_id 75 is 1.7480459118239686
# Prediction for 24980 user_id for item_id 76 is 1.1694282241921468
# Prediction for 24980 user_id for item_id 77 is 1.1691639302007364
# Prediction for 24980 user_id for item_id 78 is 1.5118196236096626
# Prediction for 24980 user_id for item_id 79 is 0.19147107761594617
# Prediction for 24980 user_id for item_id 80 is 1.041528156027666
# Prediction for 24980 user_id for item_id 81 is 0.5035925659943314
# Prediction for 24980 user_id for item_id 82 is 0.7970865732747343
# Prediction for 24980 user_id for item_id 83 is 1.184131956785819
# Prediction for 24980 user_id for item_id 84 is 1.5571109604944062
# Prediction for 24980 user_id for item_id 85 is 1.5108965076374206
# Prediction for 24980 user_id for item_id 86 is 0.8967023557979684
# Prediction for 24980 user_id for item_id 87 is 1.371358102090665
# Prediction for 24980 user_id for item_id 88 is 0.9588351470344534
# Prediction for 24980 user_id for item_id 89 is 1.3821490900750728
# Prediction for 24980 user_id for item_id 90 is 1.0857999852759557
# Prediction for 24980 user_id for item_id 91 is 0.8555701662855174
# Prediction for 24980 user_id for item_id 92 is 0.45279138893483883
# Prediction for 24980 user_id for item_id 93 is 1.445742937282867
# Prediction for 24980 user_id for item_id 94 is 1.0719660987221757
# Prediction for 24980 user_id for item_id 95 is 0.9006033456401116
# Prediction for 24980 user_id for item_id 96 is 1.4240679674248689
# Prediction for 24980 user_id for item_id 97 is 0.9652247114128939
# Prediction for 24980 user_id for item_id 98 is 1.3941155845097393
# Prediction for 24980 user_id for item_id 99 is 1.0127070990202847
# Prediction for 24981 user_id for item_id 0 is 0.48723786513505657
# Prediction for 24981 user_id for item_id 1 is 1.3809352756903375
# Prediction for 24981 user_id for item_id 2 is 1.4539659696608818
# Prediction for 24981 user_id for item_id 3 is 1.0432933733279761
# Prediction for 24981 user_id for item_id 5 is 1.4765876506404394
# Prediction for 24981 user_id for item_id 8 is 1.671731794015122
# Prediction for 24981 user_id for item_id 9 is 0.9337964431889172
# Prediction for 24981 user_id for item_id 10 is 1.1728526512861523
# Prediction for 24981 user_id for item_id 11 is 0.6763448036792225
# Prediction for 24981 user_id for item_id 13 is 1.1505480723457615
# Prediction for 24981 user_id for item_id 21 is 1.6448371459207833
# Prediction for 24981 user_id for item_id 22 is 1.2094683881645742
# Prediction for 24981 user_id for item_id 23 is 0.654552168086371
# Prediction for 24981 user_id for item_id 24 is 0.34492182680443984
# Prediction for 24981 user_id for item_id 29 is 1.2884242210220584
# Prediction for 24981 user_id for item_id 32 is 1.631695850154369
# Prediction for 24981 user_id for item_id 33 is 0.07254014268874817
# Prediction for 24981 user_id for item_id 36 is 1.3524810215188023
# Prediction for 24981 user_id for item_id 37 is 0.4529970018294287
# Prediction for 24981 user_id for item_id 39 is 0.7036125588052481
# Prediction for 24981 user_id for item_id 40 is 1.227327780478923
# Prediction for 24981 user_id for item_id 42 is 1.3543464999668513
# Prediction for 24981 user_id for item_id 43 is 1.3671617449478375
# Prediction for 24981 user_id for item_id 44 is 0.8761176514917212
# Prediction for 24981 user_id for item_id 46 is 1.2756432802138387
# Prediction for 24981 user_id for item_id 50 is 0.48487350583200706
# Prediction for 24981 user_id for item_id 51 is 1.090669557454779
# Prediction for 24981 user_id for item_id 56 is 1.3927854672577848
# Prediction for 24981 user_id for item_id 57 is 0.5905076654319201
# Prediction for 24981 user_id for item_id 58 is 1.6297602076704212
# Prediction for 24981 user_id for item_id 59 is 1.352601712661489
# Prediction for 24981 user_id for item_id 62 is 0.4154003926886578
# Prediction for 24981 user_id for item_id 63 is 1.184023104237286
# Prediction for 24981 user_id for item_id 66 is 1.6090592324386783
# Prediction for 24981 user_id for item_id 69 is 1.2369315027473282
# Prediction for 24981 user_id for item_id 70 is 1.4938857266033005
# Prediction for 24981 user_id for item_id 71 is 1.1804968548963768
# Prediction for 24981 user_id for item_id 72 is 0.6495258581915961
# Prediction for 24981 user_id for item_id 73 is 1.0479450126917202
# Prediction for 24981 user_id for item_id 75 is 1.5034321049432202
# Prediction for 24981 user_id for item_id 76 is 0.5332340981356454
# Prediction for 24981 user_id for item_id 77 is 0.8504587009922729
# Prediction for 24981 user_id for item_id 78 is 1.0179584192016773
# Prediction for 24981 user_id for item_id 80 is 1.0534275872013699
# Prediction for 24981 user_id for item_id 81 is 0.6036260411044655
# Prediction for 24981 user_id for item_id 82 is 0.6514182265073736
# Prediction for 24981 user_id for item_id 83 is 1.444560582728291
# Prediction for 24981 user_id for item_id 84 is 1.29810522395768
# Prediction for 24981 user_id for item_id 85 is 1.390749457126314
# Prediction for 24981 user_id for item_id 86 is 0.8731346185553722
# Prediction for 24981 user_id for item_id 87 is 1.2959998140599707
# Prediction for 24981 user_id for item_id 88 is 1.0983137614212781
# Prediction for 24981 user_id for item_id 89 is 1.3788619304158825
# Prediction for 24981 user_id for item_id 90 is 1.1234943934713095
# Prediction for 24981 user_id for item_id 91 is 0.9625568210975044
# Prediction for 24981 user_id for item_id 92 is 0.4625606738455052
# Prediction for 24981 user_id for item_id 93 is 0.8961567889450737
# Prediction for 24981 user_id for item_id 94 is 1.0560669377308196
# Prediction for 24981 user_id for item_id 95 is 0.5002996413162621
# Prediction for 24981 user_id for item_id 96 is 1.412029150390018
# Prediction for 24981 user_id for item_id 97 is 1.1389573199578424
# Prediction for 24981 user_id for item_id 98 is 1.711108445548999
# Prediction for 24981 user_id for item_id 99 is 0.8699011998261345
# Prediction for 24982 user_id for item_id 71 is 0.3778675702210865
# Prediction for 24982 user_id for item_id 72 is 0.785167089139381
# Prediction for 24982 user_id for item_id 73 is 0.7171477488040172
# Prediction for 24982 user_id for item_id 74 is 1.254014216347466
# Prediction for 24982 user_id for item_id 75 is 1.0664575880468983
# Prediction for 24982 user_id for item_id 76 is 1.1076436729450072
# Prediction for 24982 user_id for item_id 77 is 0.9796479152791536
# Prediction for 24982 user_id for item_id 78 is 1.2163857239726976
# Prediction for 24982 user_id for item_id 79 is 0.16759890108955292
# Prediction for 24982 user_id for item_id 80 is 0.8978540019680623
# Prediction for 24982 user_id for item_id 81 is 0.5842346497719898
# Prediction for 24982 user_id for item_id 82 is 0.5660641023166554
# Prediction for 24982 user_id for item_id 83 is 1.0803408013869487
# Prediction for 24982 user_id for item_id 84 is 0.946239104792672
# Prediction for 24982 user_id for item_id 85 is 1.0519433820537074
# Prediction for 24982 user_id for item_id 87 is 0.8975895487368908
# Prediction for 24982 user_id for item_id 88 is 0.5888315031267958
# Prediction for 24982 user_id for item_id 89 is 1.1714853604364788
# Prediction for 24982 user_id for item_id 90 is 0.7229419931356633
# Prediction for 24982 user_id for item_id 91 is 0.6359899495999094
# Prediction for 24982 user_id for item_id 92 is 0.3874403658302527
# Prediction for 24982 user_id for item_id 93 is 1.3543428135289854
# Prediction for 24982 user_id for item_id 94 is 0.8224373354621242
# Prediction for 24982 user_id for item_id 95 is 0.6887568709706807
# Prediction for 24982 user_id for item_id 96 is 0.967513397830171
# Prediction for 24982 user_id for item_id 97 is 0.7501386208898068
# Prediction for 24982 user_id for item_id 98 is 1.1110631193041585
# Prediction for 24982 user_id for item_id 99 is 0.6430768149735772

# %%
test_idx
# Out:
# (array([    0,     0,     0, ..., 24982, 24982, 24982]),
#  array([70, 71, 72, ..., 97, 98, 99]))

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 5), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=25.715734
# Iteration 5/100:	MSE=24.490774
# Iteration 10/100:	MSE=23.824339
# Iteration 15/100:	MSE=23.021349
# Iteration 20/100:	MSE=21.523492
# Iteration 25/100:	MSE=19.060529
# Iteration 30/100:	MSE=17.849517
# Iteration 35/100:	MSE=17.500716
# Iteration 40/100:	MSE=17.346665
# Iteration 45/100:	MSE=17.244011
# Iteration 50/100:	MSE=17.152458
# Iteration 55/100:	MSE=17.051838
# Iteration 60/100:	MSE=16.929645
# Iteration 65/100:	MSE=16.782651
# Iteration 70/100:	MSE=16.618960
# Iteration 75/100:	MSE=16.451877
# Iteration 80/100:	MSE=16.289665
# Iteration 85/100:	MSE=16.133538
# Iteration 90/100:	MSE=15.984144
# Iteration 95/100:	MSE=15.846324

# %%
jester_nan.iloc[55,13]
# Out:
# 6.07

# %%
df_items = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true')
df_users = pd.read_excel('https://github.com/albanda/CE888/blob/master/lab4-recommender/movies_latent_factors.xlsx?raw=true', sheet_name=1)

# %%
df_users.set_index('User', inplace=True)

# %%
df_items.set_index('Movie ID', inplace=True)

# %%
df_items[df_items['Factor15'] == df_items['Factor15'].min()]
# Out:
#                                                       Title  ...  Factor15
# Movie ID                                                     ...
# 22        Pirates of the Caribbean: The Curse of the Bla...  ... -2.292566
#
# [1 rows x 16 columns]

# %%
items_latent = df_items.drop('Title', axis=1).values

# %%
user_latent = df_users.values

# %%
user_latent.shape
# Out:
# (25, 15)

# %%
items_latent.shape
# Out:
# (100, 15)

# %%
def predict_movie_rating(user, movie):
  user_arr = df_users.loc[user].values
  movie_arr = df_items.loc[movie].drop('Title').values
  return user_arr.dot(movie_arr)

# %%
def top_n_recommendation(user, n):
  pred = {}
  for movie in df_items.index:
    pred[movie] = predict_movie_rating(user, movie)
  pred = dict(sorted(pred.items(), key=lambda kv: kv[1], reverse=True))
  movies = list(pred.keys())
  return movies[:n]

# %%
predict_movie_rating(783, 807)
# Out:
# -0.08373521823436945

# %%
predict_movie_rating(156, 9331)
# Out:
# -0.041432658849076896

# %%
top_n_recommendation(4940, 3)
# Out:
# [13, 278, 603]

# %%
df_items.loc[top_n_recommendation(1882, 2)]['Title']
# Out:
# Movie ID
# 604    The Matrix Reloaded (2003)
# 603             The Matrix (1999)
# Name: Title, dtype: object
